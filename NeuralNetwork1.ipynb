# %% [markdown]
# <a href="https://colab.research.google.com/github/Mina-T/Machine-learning/blob/main/NeuralNetwork1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Make classification data

# %%
from sklearn.datasets import make_circles

# %%
n_samples = 1000
data, labels = make_circles(n_samples,
                           noise = 0.03,
                           random_state= 42)

# %%
data.shape, labels.shape, type(data), type(labels)
# Out:
# ((1000, 2), (1000,), numpy.ndarray, numpy.ndarray)

# %%
import matplotlib.pyplot as plt
plt.scatter(x = data[:,0],
            y = data[:,1],
            c = labels)

# %%
import torch
data = torch.from_numpy(data).type(torch.float)
labels = torch.from_numpy(labels).type(torch.float)

# %% [markdown]
# Split data

# %%
from sklearn.model_selection import train_test_split

# %%
training_data, testing_data, training_label, testing_label = train_test_split(data,
                                                                labels,
                                                                test_size = 0.2,
                                                                random_state = 42)

# %% [markdown]
# make model

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cpu'

# %%
training_data.shape
# Out:
# torch.Size([800, 2])
